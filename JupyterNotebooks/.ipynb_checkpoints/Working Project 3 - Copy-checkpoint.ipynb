# %% [markdown]
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
# from sqlalchemy import create_engine
# !pip install seaborn
# import seaborn as sns
# %matplotlib inline

# %%
import os
import sys
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np 
from sqlalchemy import create_engine, Table, MetaData, select

# %%
# Be sur to configure PostgreSQL in the API folder
sqlconfig = os.path.join("..","API","PostgreSQL.py")

if not os.path.exists(sqlconfig):
    with open(sqlconfig, 'w') as file:
        file.write("connectionString = ''\nconnectionStringLocal = ''\nuser = ''\npassword = ''\nhost = ''\nport = ''")
    print(f"Configuration file has been created")
else:
    print(f"Configuration file already exists, importing...")

# Import the configuration     
sys.path.insert(1,"../API")
import PostgreSQL
# Out:
# Configuration file already exists, importing...

# %%
# Pulling data from PostgreSQL server
engine = create_engine(PostgreSQL.connectionString)
query = 'SELECT * FROM "steam_games"'
data = pd.read_sql_query(query, con = engine)
data.head()
# Out:
#      AppID                                Name Release date Estimated owners  \
# 0  1968760  Legend of Rome - The Wrath of Mars   2022-05-05        0 - 20000
# 1   434030       Aerofly FS 2 Flight Simulator   2017-11-20  100000 - 200000
# 2   262150                   Vanguard Princess   2014-03-03  200000 - 500000
# 3  1192900                      IRON REBELLION   2021-11-09   50000 - 100000
# 4   231330                 Deadfall Adventures   2013-11-15  100000 - 200000
#
#    Peak CCU  Required age  Price  DLC count  \
# 0         2             0   9.99          0
# 1        19             0  37.49         23
# 2         1             0   2.49          7
# 3         2             0  11.99          0
# 4         4             0  19.99          0
#
#                                       About the game  \
# 0  When the Roman people honored a simple warrior...
# 1  Aerofly FS 2 lets you explore the world of fly...
# 2  Government experiments on a young girl trigger...
# 3  WHAT IS IRON REBELLION? Iron Rebellion is all ...
# 4  Deadfall Adventures is an action-driven first-...
#
#                                  Supported languages  ...  Linux Positive  \
# 0                              ['English', 'German']  ...  False        0
# 1                    ['English', 'German', 'French']  ...   True     1490
# 2                                        ['English']  ...   True     2014
# 3                                        ['English']  ...  False      168
# 4  ['English', 'German', 'Polish', 'French', 'Rus...  ...   True     1716
#
#   Negative Achievements Recommendations  \
# 0        0            0               0
# 1      408            0            1831
# 2      841            0            1477
# 3       39            0             186
# 4      628           50            1140
#
#                                                Notes          Developers  \
# 0                                               None          magnussoft
# 1                                               None               IPACS
# 2                                               None      Tomoaki Sugeno
# 3  Iron Rebellion has elements of sci-fi combat w...  Black Beach Studio
# 4                                               None         The Farm 51
#
#            Publishers                                         Categories  \
# 0          magnussoft                      {Single-player,"Steam Cloud"}
# 1               IPACS               {Single-player,"Controller Support"}
# 2           eigoMANGA  {Single-player,Multi-player,PvP,PvP,"Shared/Sp...
# 3  Black Beach Studio  {Multi-player,PvP,PvP,Co-op,Co-op,Cross-Platform}
# 4          THQ Nordic  {Single-player,Multi-player,Co-op,"Steam Achie...
#
#                              Genres
# 0                          {Casual}
# 1  {Action,Indie,Racing,Simulation}
# 2             {Action,Casual,Indie}
# 3     {Action,Indie,"Early Access"}
# 4                {Action,Adventure}
#
# [5 rows x 27 columns]

# %%
data.shape
# Out:
# (10594, 27)

# %%
data.head()
# Out:
#      AppID                                Name Release date Estimated owners  \
# 0  1968760  Legend of Rome - The Wrath of Mars   2022-05-05        0 - 20000
# 1   434030       Aerofly FS 2 Flight Simulator   2017-11-20  100000 - 200000
# 2   262150                   Vanguard Princess   2014-03-03  200000 - 500000
# 3  1192900                      IRON REBELLION   2021-11-09   50000 - 100000
# 4   231330                 Deadfall Adventures   2013-11-15  100000 - 200000
#
#    Peak CCU  Required age  Price  DLC count  \
# 0         2             0   9.99          0
# 1        19             0  37.49         23
# 2         1             0   2.49          7
# 3         2             0  11.99          0
# 4         4             0  19.99          0
#
#                                       About the game  \
# 0  When the Roman people honored a simple warrior...
# 1  Aerofly FS 2 lets you explore the world of fly...
# 2  Government experiments on a young girl trigger...
# 3  WHAT IS IRON REBELLION? Iron Rebellion is all ...
# 4  Deadfall Adventures is an action-driven first-...
#
#                                  Supported languages  ...  Linux Positive  \
# 0                              ['English', 'German']  ...  False        0
# 1                    ['English', 'German', 'French']  ...   True     1490
# 2                                        ['English']  ...   True     2014
# 3                                        ['English']  ...  False      168
# 4  ['English', 'German', 'Polish', 'French', 'Rus...  ...   True     1716
#
#   Negative Achievements Recommendations  \
# 0        0            0               0
# 1      408            0            1831
# 2      841            0            1477
# 3       39            0             186
# 4      628           50            1140
#
#                                                Notes          Developers  \
# 0                                               None          magnussoft
# 1                                               None               IPACS
# 2                                               None      Tomoaki Sugeno
# 3  Iron Rebellion has elements of sci-fi combat w...  Black Beach Studio
# 4                                               None         The Farm 51
#
#            Publishers                                         Categories  \
# 0          magnussoft                      {Single-player,"Steam Cloud"}
# 1               IPACS               {Single-player,"Controller Support"}
# 2           eigoMANGA  {Single-player,Multi-player,PvP,PvP,"Shared/Sp...
# 3  Black Beach Studio  {Multi-player,PvP,PvP,Co-op,Co-op,Cross-Platform}
# 4          THQ Nordic  {Single-player,Multi-player,Co-op,"Steam Achie...
#
#                              Genres
# 0                          {Casual}
# 1  {Action,Indie,Racing,Simulation}
# 2             {Action,Casual,Indie}
# 3     {Action,Indie,"Early Access"}
# 4                {Action,Adventure}
#
# [5 rows x 27 columns]

# %%
df = data.copy()

# %%
y = df['Peak CCU']
x= df['Price']
plt.title("Price vs Peak Player Counts")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

plt.scatter(x, y)
plt.show()

# %%
df['Price'] = df['Price'].astype(int).copy()

print(df.dtypes)

print(df)
# Out:
# AppID                            int64
# Name                            object
# Release date            datetime64[ns]
# Estimated owners                object
# Peak CCU                         int64
# Required age                     int64
# Price                            int32
# DLC count                        int64
# About the game                  object
# Supported languages             object
# Full audio languages            object
# Reviews                         object
# Website                         object
# Support url                     object
# Support email                   object
# Windows                           bool
# Mac                               bool
# Linux                             bool
# Positive                         int64
# Negative                         int64
# Achievements                     int64
# Recommendations                  int64
# Notes                           object
# Developers                      object
# Publishers                      object
# Categories                      object
# Genres                          object
# dtype: object
#          AppID                                Name Release date  \
# 0      1968760  Legend of Rome - The Wrath of Mars   2022-05-05
# 1       434030       Aerofly FS 2 Flight Simulator   2017-11-20
# 2       262150                   Vanguard Princess   2014-03-03
# 3      1192900                      IRON REBELLION   2021-11-09
# 4       231330                 Deadfall Adventures   2013-11-15
# ...        ...                                 ...          ...
# 10589  2707500                     ROKO'S BASILISK   2024-01-05
# 10590  2710320                         THE DESCENT   2024-01-05
# 10591  2719650                      Project XSTING   2024-01-05
# 10592  2234690             The Day Before You Gone   2024-01-05
# 10593  2633490                        Shadow Vault   2024-01-06
#
#       Estimated owners  Peak CCU  Required age  Price  DLC count  \
# 0            0 - 20000         2             0      9          0
# 1      100000 - 200000        19             0     37         23
# 2      200000 - 500000         1             0      2          7
# 3       50000 - 100000         2             0     11          0
# 4      100000 - 200000         4             0     19          0
# ...                ...       ...           ...    ...        ...
# 10589        0 - 20000         1             0      1          0
# 10590        0 - 20000         4             0      6          0
# 10591        0 - 20000         3             0      7          0
# 10592    20000 - 50000         3             0      7          2
# 10593        0 - 20000         1             0      9          0
#
#                                           About the game  \
# 0      When the Roman people honored a simple warrior...
# 1      Aerofly FS 2 lets you explore the world of fly...
# 2      Government experiments on a young girl trigger...
# 3      WHAT IS IRON REBELLION? Iron Rebellion is all ...
# 4      Deadfall Adventures is an action-driven first-...
# ...                                                  ...
# 10589  'We have no idea what you'll find there, but w...
# 10590  Experience 'The Descent,' a first-person psych...
# 10591  SUBJECT ON THE RUN! You’re tired of being a la...
# 10592  Set in a medieval fantasy world, an era filled...
# 10593  'As I walk through the shadow of death, I fear...
#
#                                      Supported languages  ...  Linux Positive  \
# 0                                  ['English', 'German']  ...  False        0
# 1                        ['English', 'German', 'French']  ...   True     1490
# 2                                            ['English']  ...   True     2014
# 3                                            ['English']  ...  False      168
# 4      ['English', 'German', 'Polish', 'French', 'Rus...  ...   True     1716
# ...                                                  ...  ...    ...      ...
# 10589  ['English', 'Spanish - Spain', 'Portuguese - B...  ...  False        9
# 10590  ['English', 'French', 'Italian', 'German', 'Sp...  ...  False        8
# 10591  ['English', 'Spanish - Spain', 'Portuguese - B...  ...  False        5
# 10592                             ['English', 'Russian']  ...  False       11
# 10593                                        ['English']  ...  False        0
#
#       Negative Achievements Recommendations  \
# 0            0            0               0
# 1          408            0            1831
# 2          841            0            1477
# 3           39            0             186
# 4          628           50            1140
# ...        ...          ...             ...
# 10589        0            3               0
# 10590        1           12               0
# 10591        0           42               0
# 10592        0           30               0
# 10593        0            0               0
#
#                                                    Notes  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      Iron Rebellion has elements of sci-fi combat w...
# 4                                                   None
# ...                                                  ...
# 10589                                               None
# 10590  The game contains images of scenes of violence...
# 10591                                               None
# 10592                                               None
# 10593                                               None
#
#                                               Developers          Publishers  \
# 0                                             magnussoft          magnussoft
# 1                                                  IPACS               IPACS
# 2                                         Tomoaki Sugeno           eigoMANGA
# 3                                     Black Beach Studio  Black Beach Studio
# 4                                            The Farm 51          THQ Nordic
# ...                                                  ...                 ...
# 10589                                               Roko                Roko
# 10590                                    Celeritas Games     Celeritas Games
# 10591                                        Saucy Melon         Saucy Melon
# 10592                                    Aequalis Studio     Aequalis Studio
# 10593  Mayhem Studios,ZOOM Platform Media,Jordan Free...      Strategy First
#
#                                               Categories  \
# 0                          {Single-player,"Steam Cloud"}
# 1                   {Single-player,"Controller Support"}
# 2      {Single-player,Multi-player,PvP,PvP,"Shared/Sp...
# 3      {Multi-player,PvP,PvP,Co-op,Co-op,Cross-Platform}
# 4      {Single-player,Multi-player,Co-op,"Steam Achie...
# ...                                                  ...
# 10589               {Single-player,"Steam Achievements"}
# 10590               {Single-player,"Steam Achievements"}
# 10591  {Single-player,"Steam Achievements","Steam Clo...
# 10592               {Single-player,"Steam Achievements"}
# 10593                      {Single-player,"Steam Cloud"}
#
#                                      Genres
# 0                                  {Casual}
# 1          {Action,Indie,Racing,Simulation}
# 2                     {Action,Casual,Indie}
# 3             {Action,Indie,"Early Access"}
# 4                        {Action,Adventure}
# ...                                     ...
# 10589                               {Indie}
# 10590                    {Indie,Simulation}
# 10591  {Action,Casual,Indie,"Early Access"}
# 10592                     {Adventure,Indie}
# 10593                                 {RPG}
#
# [10594 rows x 27 columns]

# %%
#top_10 = df['games.csv'].groupby(df('Name')['Peak CCU']).value_count()
#top_10.plot(kind='bar',figsize=(10,8))
#plt.title('Most Popular Game by Peak Player Count')
#plt.show()

# %%
# Sorting games by Peak CCU
top_10 = df.sort_values(by='Peak CCU', ascending=False).head(10).copy()

# Visualizing those with a bar graph
plt.bar(range(len(top_10)), top_10['Peak CCU'])
plt.xticks(range(len(top_10)), top_10['Name'].tolist(), rotation=80)
plt.xlabel('Game Name')
plt.ylabel('Peak CCU')
plt.title('Top 10 Most Popular Steam Games by Peak CCU')
plt.show()

# %% [markdown]
# Name =[{"Name"}]
# Price =[{"Name"}]

# %%
top_10 = df.sort_values(by='Peak CCU', ascending=False).head(10).copy()

# Visualizing those with a bar graph
plt.bar(range(len(top_10)), top_10['Peak CCU'])
plt.xticks(range(len(top_10)), top_10['Name'].tolist(), rotation=80)
plt.xlabel('Game Name')
plt.ylabel('Peak CCU')
plt.title('Top 10 Most Popular Steam Games by Peak CCU')
plt.show()

# %%
y = np.array([])

plt.title("Supported languages")

plt.pie(y)
plt.show()
