# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np
#Connect to PostgreSQL and import steam_games:
# Out:
#          AppID                               Name  Release date  \
# 69429   990080                    Hogwarts Legacy  Feb 10, 2023
# 46158      730   Counter-Strike: Global Offensive  Aug 21, 2012
# 17585      570                             Dota 2   Jul 9, 2013
# 70064  1326470                 Sons Of The Forest  Feb 23, 2023
# 47658  1599340                           Lost Ark  Feb 11, 2022
# 8885    578080                PUBG: BATTLEGROUNDS  Dec 21, 2017
# 736    1172470                      Apex Legends™   Nov 4, 2020
# 65186  1938090  Call of Duty®: Modern Warfare® II  Oct 27, 2022
# 57205   271590                 Grand Theft Auto V  Apr 13, 2015
# 81830  1966720                     Lethal Company  Oct 23, 2023
#
#             Estimated owners  Peak CCU  Required age  Price  DLC count  \
# 69429     5000000 - 10000000    872138             0  59.99          1
# 46158   50000000 - 100000000    825215             0   0.00          1
# ...

# %%
# Sorting games by Peak CCU
top_10 = df.sort_values(by='Peak CCU', ascending=False).head(10)

# Visualizing those with a bar graph
plt.bar(range(len(top_10)), top_10['Peak CCU'])
plt.xticks(range(len(top_10)), top_10['Name'].tolist(), rotation=80)
plt.xlabel('Game Name')
plt.ylabel('Peak CCU')
plt.title('Top 10 Most Popular Steam Games by Peak CCU')
plt.show()
